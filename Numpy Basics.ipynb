# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np

# %%
a = np.array([[1, 2, 3],
              [4, 5, 6]])
a.shape
# Out:
# (2, 3)

# %%
a.ndim
# Out:
# 2

# %%
a.dtype
# Out:
# dtype('int32')

# %%
a.size
# Out:
# 6

# %%
arr=np.array([2,6,7,4,19,45])
np.sort(arr)
# Out:
# array([ 2,  4,  6,  7, 19, 45])

# %%
np.arange(2,15,4)
# Out:
# array([ 2,  6, 10, 14])

# %%
arr[2:]
# Out:
# array([ 7,  4, 19, 45])

# %%
b = np.arange(1, 10)

matrix = b.reshape(3, 3)

print(matrix)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
